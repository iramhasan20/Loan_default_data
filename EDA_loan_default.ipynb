# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Loan_Default.csv')

# %%
df.head()
# Out:
#       ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0  24890  2019         cf  Sex Not Available         nopre     type1
# 1  24891  2019         cf               Male         nopre     type2
# 2  24892  2019         cf               Male           pre     type1
# 3  24893  2019         cf               Male         nopre     type1
# 4  24894  2019         cf              Joint           pre     type1
#
#   loan_purpose Credit_Worthiness open_credit business_or_commercial  ...  \
# 0           p1                l1        nopc                  nob/c  ...
# 1           p1                l1        nopc                    b/c  ...
# 2           p1                l1        nopc                  nob/c  ...
# 3           p4                l1        nopc                  nob/c  ...
# 4           p1                l1        nopc                  nob/c  ...
#
#    credit_type  Credit_Score  co-applicant_credit_type    age  \
# ...

# %%
df.tail()
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 148665  173555  2019         cf  Sex Not Available         nopre     type1
# 148666  173556  2019         cf               Male         nopre     type1
# 148667  173557  2019         cf               Male         nopre     type1
# 148668  173558  2019         cf             Female         nopre     type1
# 148669  173559  2019         cf             Female         nopre     type1
#
#        loan_purpose Credit_Worthiness open_credit business_or_commercial  ...  \
# 148665           p3                l1        nopc                  nob/c  ...
# 148666           p1                l1        nopc                  nob/c  ...
# 148667           p4                l1        nopc                  nob/c  ...
# 148668           p4                l1        nopc                  nob/c  ...
# 148669           p3                l1        nopc                  nob/c  ...
#
# ...

# %%
df.shape
# Out:
# (148670, 34)

# %%
df.describe().T #to view in transpose format
# Out:
#                          count           mean            std           min  \
# ID                    148670.0   99224.500000   42917.476598  24890.000000
# year                  148670.0    2019.000000       0.000000   2019.000000
# loan_amount           148670.0  331117.743997  183909.310127  16500.000000
# rate_of_interest      112231.0       4.045476       0.561391      0.000000
# Interest_rate_spread  112031.0       0.441656       0.513043     -3.638000
# Upfront_charges       109028.0    3224.996127    3251.121510      0.000000
# term                  148629.0     335.136582      58.409084     96.000000
# property_value        133572.0  497893.465696  359935.315562   8000.000000
# income                139520.0    6957.338876    6496.586382      0.000000
# Credit_Score          148670.0     699.789103     115.875857    500.000000
# LTV                   133572.0      72.746457      39.967603      0.967478
# ...

# %%
(df.describe()).round(2).T
# Out:
#                          count       mean        std       min        25%  \
# ID                    148670.0   99224.50   42917.48  24890.00   62057.25
# year                  148670.0    2019.00       0.00   2019.00    2019.00
# loan_amount           148670.0  331117.74  183909.31  16500.00  196500.00
# rate_of_interest      112231.0       4.05       0.56      0.00       3.62
# Interest_rate_spread  112031.0       0.44       0.51     -3.64       0.08
# Upfront_charges       109028.0    3225.00    3251.12      0.00     581.49
# term                  148629.0     335.14      58.41     96.00     360.00
# property_value        133572.0  497893.47  359935.32   8000.00  268000.00
# income                139520.0    6957.34    6496.59      0.00    3720.00
# Credit_Score          148670.0     699.79     115.88    500.00     599.00
# LTV                   133572.0      72.75      39.97      0.97      60.47
# Status                148670.0       0.25       0.43      0.00       0.00
# ...

# %%
df.describe(include='all').round(2).T
# Out:
#                               count unique       top    freq       mean  \
# ID                         148670.0    NaN       NaN     NaN    99224.5
# year                       148670.0    NaN       NaN     NaN     2019.0
# loan_limit                   145326      2        cf  135348        NaN
# Gender                       148670      4      Male   42346        NaN
# approv_in_adv                147762      2     nopre  124621        NaN
# loan_type                    148670      3     type1  113173        NaN
# loan_purpose                 148536      4        p3   55934        NaN
# Credit_Worthiness            148670      2        l1  142344        NaN
# open_credit                  148670      2      nopc  148114        NaN
# business_or_commercial       148670      2     nob/c  127908        NaN
# loan_amount                148670.0    NaN       NaN     NaN  331117.74
# rate_of_interest           112231.0    NaN       NaN     NaN       4.05
# ...

# %%
numerical_cols = ['loan_amount', 'rate_of_interest', 'Interest_rate_spread', 'Upfront_charges',
                  'term', 'property_value', 'income', 'Credit_Score', 'LTV', 'dtir1']

categorical_cols = ['Gender', 'approv_in_adv', 'loan_type', 'loan_purpose', 'Credit_Worthiness',
                    'open_credit', 'business_or_commercial', 'Neg_ammortization', 'interest_only',
                    'lump_sum_payment', 'construction_type', 'occupancy_type', 'Secured_by',
                    'total_units', 'credit_type', 'co-applicant_credit_type', 'age',
                    'submission_of_application', 'Region', 'Security_Type']

# %%
for col in numerical_cols:
    plt.figure(figsize=(8, 4))
    sns.histplot(df[col], kde=True, bins=30, color='skyblue')
    plt.title(f'Distribution of {col}')
    plt.tight_layout()
    plt.show()

# %%
for col in numerical_cols:
    plt.figure(figsize=(6, 3))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.tight_layout()
    plt.show()

# %%
# Count plots for categorical variables
for col in categorical_cols:
    plt.figure(figsize=(7, 3))
    sns.countplot(data=df, x=col, order=df[col].value_counts().index)
    plt.xticks(rotation=45)
    plt.title(f'Count of {col}')
    plt.tight_layout()
    plt.show()

# %%
correlation_matrix = df[numerical_cols].corr()
correlation_matrix
# Out:
#                       loan_amount  rate_of_interest  Interest_rate_spread  \
# loan_amount              1.000000         -0.150844             -0.377272
# rate_of_interest        -0.150844          1.000000              0.614908
# Interest_rate_spread    -0.377272          0.614908              1.000000
# Upfront_charges          0.065556         -0.076473              0.033037
# term                     0.174474          0.209330             -0.157139
# property_value           0.734249         -0.122613             -0.334571
# income                   0.456065         -0.041809             -0.151333
# Credit_Score             0.004438         -0.001331             -0.001738
# LTV                      0.038869         -0.000220              0.040257
# dtir1                    0.015029          0.055124              0.078178
#
#                       Upfront_charges      term  property_value    income  \
# loan_amount                  0.065556  0.174474        0.734249  0.456065
# ...

# %%
# Correlation heatmap
plt.figure(figsize=(10, 8))
corr = df[numerical_cols + ['Status']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("📌 Correlation Heatmap")
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-24-0e18a2685dc1>:6: UserWarning: Glyph 128204 (\N{PUSHPIN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128204 (\N{PUSHPIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#counting males and females
count = df.value_counts('Gender')
percent = count / count.sum() * 100
print(percent)
# Out:
# Gender
# Male                 28.483218
# Joint                27.846237
# Sex Not Available    25.330598
# Female               18.339948
# Name: count, dtype: float64

# %%
# Count how many males and females defaulted
default_by_gender = df[df['Status'] == 1]['Gender'].value_counts()

print("Number of Defaults by Gender:")
print(default_by_gender)
# Out:
# Number of Defaults by Gender:
# Gender
# Male                 11091
# Sex Not Available    10767
# Joint                 7933
# Female                6848
# Name: count, dtype: int64

# %%
# Total count of each gender
total_by_gender = df['Gender'].value_counts()

# Defaults count by gender
default_by_gender = df[df['Status'] == 1]['Gender'].value_counts()

# Percentage of defaults within each gender
default_percent = (default_by_gender / total_by_gender) * 100
default_percent = default_percent.round(2)

print("Percentage of Defaults by Gender:")
print(default_percent)
# Out:
# Percentage of Defaults by Gender:
# Gender
# Female               25.12
# Joint                19.16
# Male                 26.19
# Sex Not Available    28.59
# Name: count, dtype: float64

# %%
#counting region wise
count_region = df.value_counts('Region')
percent_region = count_region / count_region.sum() * 100
percent_region
# Out:
# Region
# North         50.260308
# south         43.059124
# central        5.849869
# North-East     0.830699
# Name: count, dtype: float64

# %%
default_by_region = df[df['Status'] == 1]['Region'].value_counts()

print("Number of Defaults by Region:")
print(default_by_region)
# Out:
# Number of Defaults by Region:
# Region
# south         17047
# North         16821
# central        2395
# North-East      376
# Name: count, dtype: int64

# %%
# Total count of each gender
total_by_region = df['Region'].value_counts()

# Defaults count by gender
default_by_region = df[df['Status'] == 1]['Region'].value_counts()

# Percentage of defaults within each gender
default_percent = (default_by_region / total_by_region) * 100
default_percent = default_percent.round(2)

print("Percentage of Defaults by Region:")
print(default_percent)
# Out:
# Percentage of Defaults by Region:
# Region
# North         22.51
# North-East    30.45
# central       27.54
# south         26.63
# Name: count, dtype: float64

# %%
df.isnull().sum()
# Out:
# ID                               0
# year                             0
# loan_limit                    3344
# Gender                           0
# approv_in_adv                  908
# loan_type                        0
# loan_purpose                   134
# Credit_Worthiness                0
# open_credit                      0
# business_or_commercial           0
# loan_amount                      0
# rate_of_interest             36439
# Interest_rate_spread         36639
# Upfront_charges              39642
# term                            41
# Neg_ammortization              121
# interest_only                    0
# lump_sum_payment                 0
# property_value               15098
# construction_type                0
# occupancy_type                   0
# Secured_by                       0
# total_units                      0
# income                        9150
# credit_type                      0
# Credit_Score                     0
# co-applicant_credit_type         0
# ...

# %%
df2= df.dropna()

# %%
df2
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 2        24892  2019         cf               Male           pre     type1
# 4        24894  2019         cf              Joint           pre     type1
# 5        24895  2019         cf              Joint           pre     type1
# 6        24896  2019         cf              Joint           pre     type1
# 8        24898  2019         cf              Joint         nopre     type1
# ...        ...   ...        ...                ...           ...       ...
# 148665  173555  2019         cf  Sex Not Available         nopre     type1
# 148666  173556  2019         cf               Male         nopre     type1
# 148667  173557  2019         cf               Male         nopre     type1
# 148668  173558  2019         cf             Female         nopre     type1
# 148669  173559  2019         cf             Female         nopre     type1
#
# ...

# %%
df2.isnull().sum()
# Out:
# ID                           0
# year                         0
# loan_limit                   0
# Gender                       0
# approv_in_adv                0
# loan_type                    0
# loan_purpose                 0
# Credit_Worthiness            0
# open_credit                  0
# business_or_commercial       0
# loan_amount                  0
# rate_of_interest             0
# Interest_rate_spread         0
# Upfront_charges              0
# term                         0
# Neg_ammortization            0
# interest_only                0
# lump_sum_payment             0
# property_value               0
# construction_type            0
# occupancy_type               0
# Secured_by                   0
# total_units                  0
# income                       0
# credit_type                  0
# Credit_Score                 0
# co-applicant_credit_type     0
# age                          0
# submission_of_application    0
# LTV                          0
# ...

# %%
df2.shape
# Out:
# (98187, 34)

# %%
for col in numerical_cols:
    plt.figure(figsize=(8, 4))
    sns.histplot(df2[col], kde=True, bins=30, color='skyblue')
    plt.title(f'Distribution of {col}')
    plt.tight_layout()
    plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(10, 8))
corr = df2[numerical_cols + ['Status']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

# %%
for col in numerical_cols:
    plt.figure(figsize=(6, 3))
    sns.boxplot(x=df2[col])
    plt.title(f'Boxplot of {col}')
    plt.tight_layout()
    plt.show()

# %%
df2.value_counts('term')
# Out:
# term
# 360.0    79862
# 180.0     9146
# 240.0     4350
# 324.0     1942
# 300.0      998
# 120.0      388
# 144.0      205
# 348.0      199
# 336.0      163
# 312.0      148
# 96.0       140
# 156.0      131
# 216.0       81
# 288.0       73
# 276.0       70
# 168.0       60
# 132.0       59
# 228.0       51
# 204.0       40
# 264.0       31
# 108.0       27
# 192.0       15
# 252.0        7
# 322.0        1
# Name: count, dtype: int64

# %%
df2.to_csv('cleaned_loan_data.csv', index=False)

# %%
df3 = pd.read_csv('cleaned_loan_data.csv')

# %%
df3.shape
# Out:
# (98187, 34)
